# %% [markdown]
# # Matplotlib Tutorial (Part 7)：Scatter Plots
#
# [The video which its based on](https://youtu.be/zZZ_RCwp49g)

# %%
from matplotlib import pyplot as plt
import pandas as pd
from collections import Counter
import numpy as np

# plt.style.use("seaborn")

# %%
x = np.random.randint(1, 10, 50)
y = np.random.randint(1, 10, 50)
x, y
# Out:
# (array([6, 5, 5, 8, 1, 2, 8, 9, 1, 2, 5, 1, 9, 3, 8, 8, 6, 2, 5, 7, 6, 4,
#         4, 9, 2, 4, 9, 2, 6, 8, 2, 2, 5, 9, 4, 5, 2, 4, 5, 5, 5, 7, 9, 9,
#         1, 2, 4, 2, 5, 3]),
#  array([8, 8, 4, 2, 6, 7, 5, 9, 7, 4, 1, 5, 5, 6, 2, 8, 3, 8, 4, 3, 9, 5,
#         2, 9, 4, 8, 1, 5, 3, 4, 7, 6, 3, 6, 2, 1, 3, 3, 5, 4, 4, 7, 8, 9,
#         9, 5, 6, 4, 1, 2]))

# %%
plt.scatter(x, y)
plt.show()

# %%
plt.scatter(x, y,
           s=300)
plt.show()

# %%
plt.scatter(x, y,
           s=30,
           c='green')
plt.show()

# %%
plt.scatter(x, y,
           s=30,
           c='green',
           marker='X')
plt.show()

# %%
plt.scatter(x, y,
           s=30,
           c='green',
           edgecolor='black',
           linewidth=1,
           alpha=0.3)
plt.show()

# %%
colors = np.arange(len(x))
plt.scatter(x, y,
           s=30,
           c=colors,
           edgecolor='black',
           linewidth=1,
           alpha=0.3)
plt.show()

# %%
colors = np.arange(len(x))
plt.scatter(x, y,
           s=30,
           c=colors,
           cmap='Greens',
           edgecolor='black',
           linewidth=1,
           alpha=0.5)
plt.show()

# %%
colors = np.arange(len(x))
plt.scatter(x, y,
           s=30,
           c=colors,
           cmap='Greens',
           edgecolor='black',
           linewidth=1,
           alpha=0.5)

cbar = plt.colorbar()
cbar.set_label('Satisfaction Level')

plt.show()

# %%
colors = np.arange(len(x))
sizes = np.random.randint(100, 500, len(x))

plt.scatter(x, y,
           s=30,
           c=colors,
           sizes=sizes,
           cmap='Greens',
           edgecolor='black',
           linewidth=1,
           alpha=0.5)

cbar = plt.colorbar()
cbar.set_label('Satisfaction Level')

plt.show()

# %%
colors = np.arange(len(x))
sizes = np.random.randint(100, 500, len(x))

plt.scatter(x, y,
           s=30,
           c=colors,
           sizes=sizes,
           cmap='summer',
           edgecolor='black',
           linewidth=1,
           alpha=0.5)

plt.xscale('log')
plt.yscale('log')

cbar = plt.colorbar()
cbar.set_label('Satisfaction Level')

plt.show()
