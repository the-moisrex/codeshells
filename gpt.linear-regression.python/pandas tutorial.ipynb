# %%
import pandas as pd

# create a series from a list
s = pd.Series([10, 20, 30, 40, 50])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# create a series from a dictionary
d = {"a": 10, "b": 20, "c": 30}
s = pd.Series(d)
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# create a series from a numpy array
import numpy as np
a = np.array([10, 20, 30, 40, 50])
s = pd.Series(a)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': [25, 30, 35, 40],
        'City': ['New York', 'San Francisco', 'Los Angeles', 'Chicago']}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   40        Chicago

# %%
import pandas as pd
import numpy as np

data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': np.random.randint(18, 60, size=4),
        'City': ['New York', 'San Francisco', 'Los Angeles', 'Chicago'],
        'Salary': np.random.randint(2000, 8000, size=4)}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York    2243
# 1      Bob   30  San Francisco    5285
# 2  Charlie   24    Los Angeles    4156
# 3    David   47        Chicago    6992

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': np.random.randint(18, 60, size=4),
        'City': ['New York', 'San Francisco', 'Los Angeles', 'Chicago'],
        'Salary': np.random.randint(2000, 8000, size=4)}

df = pd.DataFrame(data)

plt.bar(df['Name'], df['Age'])
plt.xlabel('Name')
plt.ylabel('Age')
plt.title('Age of People')

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# list of 100 cities in China
cities = ['Beijing', 'Shanghai', 'Guangzhou', 'Shenzhen', 'Tianjin', 'Chongqing', 'Hong Kong', 'Wuhan', 'Nanjing', 'Chengdu',
          'Hangzhou', 'Xi`an', 'Shenyang', 'Harbin', 'Suzhou', 'Qingdao', 'Jinan', 'Foshan', 'Dalian', 'Taiyuan',
          'Zhengzhou', 'Changsha', 'Changchun', 'Xiamen', 'Nanning', 'Jilin', 'Nanchang', 'Guiyang', 'Lanzhou', 'Xining',
          'Wuxi', 'Kunming', 'Hefei', 'Urumqi', 'Hohhot', 'Yinchuan', 'Zhuhai', 'Ningbo', 'Fuzhou', 'Zibo', 'Wenzhou',
          'Shaoyang', 'Xuchang', 'Xiangtan', 'Huainan', 'Yulin', 'Jiujiang', 'Linyi', 'Yantai', 'Suzhou', 'Sanming',
          'Baoding', 'Loudi', 'Hebi', 'Kaili', 'Jingdezhen', 'Zhenjiang', 'Haikou', 'Jinzhou', 'Binzhou', 'Jieyang',
          'Yibin', 'Wuzhou', 'Huaian', 'Bengbu', 'Zhangzhou', 'Tongliao', 'Tonghua', 'Xinyu', 'Hanzhong', 'Dengzhou',
          'Zhumadian', 'Yunfu', 'Hengshui', 'Lianyungang', 'Ji`an', 'Zhangqiao', 'Puyang', 'Yongzhou', 'Jiangyin',
          'Shijiazhuang', 'Ma`anshan', 'Fuyang', 'Zhanjiang', 'Maoming', 'Xiantao', 'Yangjiang', 'Huanggang', 'Chenzhou',
          'Zhangye', 'Yichun', 'Daqing', 'Weinan', 'Neijiang', 'Shaoguan', 'Shunde', 'Hetian', 'Tongling', 'Luzhou']

print (len(cities))
n_cities = 100
ages = np.random.randint(20, 60, size=n_cities)
salaries = np.random.normal(4000, 1000, size=n_cities)

df = pd.DataFrame({'City': cities, 'Age': ages, 'Salary': salaries})

plt.scatter(df['Age'], df['Salary'])
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age vs. Salary for 100 Cities in China')
plt.show()
# Out:
# 99
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 22
#      19 ages = np.random.randint(20, 60, size=n_cities)
#      20 salaries = np.random.normal(4000, 1000, size=n_cities)
# ---> 22 df = pd.DataFrame({'City': cities, 'Age': ages, 'Salary': salaries})
#      24 plt.scatter(df['Age'], df['Salary'])
#      25 plt.xlabel('Age')
#
# File ~/.conda/envs/jup/lib/python3.10/site-packages/pandas/core/frame.py:663, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     657     mgr = self._init_mgr(
#     658         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     659     )
#     661 elif isinstance(data, dict):
#     662     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 663     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# list of cities in China
cities = ['Beijing', 'Shanghai', 'Guangzhou', 'Shenzhen', 'Tianjin', 'Chongqing', 'Hong Kong', 'Wuhan', 'Nanjing', 'Chengdu',
          'Hangzhou', 'Xi`an', 'Shenyang', 'Harbin', 'Suzhou', 'Qingdao', 'Jinan', 'Foshan', 'Dalian', 'Taiyuan',
          'Zhengzhou', 'Changsha', 'Changchun', 'Xiamen', 'Nanning', 'Jilin', 'Nanchang', 'Guiyang', 'Lanzhou', 'Xining',
          'Wuxi', 'Kunming', 'Hefei', 'Urumqi', 'Hohhot', 'Yinchuan', 'Zhuhai', 'Ningbo', 'Fuzhou', 'Zibo', 'Wenzhou',
          'Shaoyang', 'Xuchang', 'Xiangtan', 'Huainan', 'Yulin', 'Jiujiang', 'Linyi', 'Yantai', 'Suzhou', 'Sanming',
          'Baoding', 'Loudi', 'Hebi', 'Kaili', 'Jingdezhen', 'Zhenjiang', 'Haikou', 'Jinzhou', 'Binzhou', 'Jieyang',
          'Yibin', 'Wuzhou', 'Huaian', 'Bengbu', 'Zhangzhou', 'Tongliao', 'Tonghua', 'Xinyu', 'Hanzhong', 'Dengzhou',
          'Zhumadian', 'Yunfu', 'Hengshui', 'Lianyungang', 'Ji`an', 'Zhangqiao', 'Puyang', 'Yongzhou', 'Jiangyin',
          'Shijiazhuang', 'Ma`anshan', 'Fuyang', 'Zhanjiang', 'Maoming', 'Xiantao', 'Yangjiang', 'Huanggang', 'Chenzhou',
          'Zhangye', 'Yichun', 'Daqing', 'Weinan', 'Neijiang', 'Shaoguan', 'Shunde', 'Hetian', 'Tongling', 'Luzhou']

n_cities = len(cities)
ages = np.random.randint(20, 60, size=n_cities)
salaries = np.random.normal(4000, 1000, size=n_cities)

df = pd.DataFrame({'City': cities, 'Age': ages, 'Salary': salaries})

plt.scatter(df['Age'], df['Salary'])
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age vs. Salary for Cities in China')
plt.show()

# %% [markdown]
# # With Duplicates

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# list of cities in China
cities = ['Beijing', 'Shanghai', 'Guangzhou', 'Shenzhen', 'Tianjin', 'Chongqing', 'Hong Kong', 'Wuhan', 'Nanjing', 'Chengdu',
          'Hangzhou', 'Xi`an', 'Shenyang', 'Harbin', 'Suzhou', 'Qingdao', 'Jinan', 'Foshan', 'Dalian', 'Taiyuan',
          'Zhengzhou', 'Changsha', 'Changchun', 'Xiamen', 'Nanning', 'Jilin', 'Nanchang', 'Guiyang', 'Lanzhou', 'Xining',
          'Wuxi', 'Kunming', 'Hefei', 'Urumqi', 'Hohhot', 'Yinchuan', 'Zhuhai', 'Ningbo', 'Fuzhou', 'Zibo', 'Wenzhou',
          'Shaoyang', 'Xuchang', 'Xiangtan', 'Huainan', 'Yulin', 'Jiujiang', 'Linyi', 'Yantai', 'Suzhou', 'Sanming',
          'Baoding', 'Loudi', 'Hebi', 'Kaili', 'Jingdezhen', 'Zhenjiang', 'Haikou', 'Jinzhou', 'Binzhou', 'Jieyang',
          'Yibin', 'Wuzhou', 'Huaian', 'Bengbu', 'Zhangzhou', 'Tongliao', 'Tonghua', 'Xinyu', 'Hanzhong', 'Dengzhou',
          'Zhumadian', 'Yunfu', 'Hengshui', 'Lianyungang', 'Ji`an', 'Zhangqiao', 'Puyang', 'Yongzhou', 'Jiangyin',
          'Shijiazhuang', 'Ma`anshan', 'Fuyang', 'Zhanjiang', 'Maoming', 'Xiantao', 'Yangjiang', 'Huanggang', 'Chenzhou',
          'Zhangye', 'Yichun', 'Daqing', 'Weinan', 'Neijiang', 'Shaoguan', 'Shunde', 'Hetian', 'Tongling', 'Luzhou',
          'Guangzhou', 'Yichun', 'Wenzhou', 'Jinin']

n_cities = len(cities)
ages = np.random.randint(20, 60, size=n_cities)
salaries = np.random.normal(4000, 1000, size=n_cities)

df = pd.DataFrame({'City': cities, 'Age': ages, 'Salary': salaries})

plt.scatter(df['Age'], df['Salary'])
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age vs. Salary for Cities in China')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# list of cities in China
cities = ['Beijing', 'Shanghai', 'Guangzhou', 'Shenzhen', 'Tianjin', 'Chongqing', 'Hong Kong', 'Wuhan', 'Nanjing', 'Chengdu',
          'Hangzhou', 'Xi`an', 'Shenyang', 'Harbin', 'Suzhou', 'Qingdao', 'Jinan', 'Foshan', 'Dalian', 'Taiyuan',
          'Zhengzhou', 'Changsha', 'Changchun', 'Xiamen', 'Nanning', 'Jilin', 'Nanchang', 'Guiyang', 'Lanzhou', 'Xining',
          'Wuxi', 'Kunming', 'Hefei', 'Urumqi', 'Hohhot', 'Yinchuan', 'Zhuhai', 'Ningbo', 'Fuzhou', 'Zibo', 'Wenzhou',
          'Shaoyang', 'Xuchang', 'Xiangtan', 'Huainan', 'Yulin', 'Jiujiang', 'Linyi', 'Yantai', 'Suzhou', 'Sanming',
          'Baoding', 'Loudi', 'Hebi', 'Kaili', 'Jingdezhen', 'Zhenjiang', 'Haikou', 'Jinzhou', 'Binzhou', 'Jieyang',
          'Yibin', 'Wuzhou', 'Huaian', 'Bengbu', 'Zhangzhou', 'Tongliao', 'Tonghua', 'Xinyu', 'Hanzhong', 'Dengzhou',
          'Zhumadian', 'Yunfu', 'Hengshui', 'Lianyungang', 'Ji`an', 'Zhangqiao', 'Puyang', 'Yongzhou', 'Jiangyin',
          'Shijiazhuang', 'Ma`anshan', 'Fuyang', 'Zhanjiang', 'Maoming', 'Xiantao', 'Yangjiang', 'Huanggang', 'Chenzhou',
          'Zhangye', 'Yichun', 'Daqing', 'Weinan', 'Neijiang', 'Shaoguan', 'Shunde', 'Hetian', 'Tongling', 'Luzhou',
          'Guangzhou', 'Yichun', 'Wenzhou', 'Jinin']

populations = [2171, 2424, 1404, 1303, 1564, 3075, 7491, 1108, 824, 1633, 632, 1235, 2725, 1003, 1093, 920, 713, 775, 631, 406,
               1053, 2898, 2929, 361, 720, 474, 508, 865, 437, 262, 473, 321, 350, 1635, 688, 968, 346, 322, 714, 1234, 619,
               308, 503, 334, 1005, 706, 650, 285, 579, 881, 262, 261, 373, 397, 426, 302, 273, 758, 482, 1413, 487, 1135,
               132, 235, 345, 371, 786, 1088, 191, 526, 423, 377, 770, 375, 230, 327, 981, 624, 226, 338, 264, 142, 796,
               398, 127, 554, 303, 463, 547, 233, 612, 101, 1488, 142, 927, 181, 570, 733, 215, 286, 1147, 132, 592, 748]

n_cities = len(cities)
ages = np.random.randint(20, 60, size=n_cities)
salaries = np.random.normal(4000, 1000, size=n_cities)

df = pd.DataFrame({'City': cities, 'Age': ages, 'Salary': salaries, 'Population': populations})

plt.scatter(df['Age'], df['Salary'])
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age vs. Salary for Cities in China')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 28
#      25 ages = np.random.randint(20, 60, size=n_cities)
#      26 salaries = np.random.normal(4000, 1000, size=n_cities)
# ---> 28 df = pd.DataFrame({'City': cities, 'Age': ages, 'Salary': salaries, 'Population': populations})
#      30 plt.scatter(df['Age'], df['Salary'])
#      31 plt.xlabel('Age')
#
# File ~/.conda/envs/jup/lib/python3.10/site-packages/pandas/core/frame.py:663, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     657     mgr = self._init_mgr(
#     658         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     659     )
#     661 elif isinstance(data, dict):
#     662     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 663     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
# ...

# %%
import pandas as pd

cols = ['Age', 'Gender', 'Hobby']
people = [
    [25, "Male", "Reading"],
    [31, "Female", "Hiking"],
    [50, "Male", "Gardening"],
    [18, "Non-binary", "Video games"],
    [42, "Female", "Yoga"],
    [28, "Male", "Playing guitar"],
    [19, "Female", "Painting"],
    [36, "Male", "Cooking"],
    [55, "Female", "Singing"],
    [24, "Male", "Running"],
    [29, "Female", "Traveling"],
    [45, "Male", "Fishing"],
    [20, "Non-binary", "Knitting"],
    [33, "Female", "Dancing"],
    [48, "Male", "Golfing"],
    [21, "Female", "Photography"],
    [27, "Male", "Playing basketball"],
    [16, "Female", "Watching movies"],
    [39, "Male", "Woodworking"],
    [60, "Female", "Reading"],
    [22, "Male", "Surfing"],
    [30, "Female", "Paintball"],
    [43, "Male", "Hunting"],
    [17, "Non-binary", "Listening to music"],
    [35, "Female", "Writing"],
    [51, "Male", "Playing poker"],
    [23, "Female", "Shopping"],
    [26, "Male", "Playing video games"],
    [49, "Female", "Sewing"],
    [41, "Male", "Camping"],
    [34, "Female", "Sculpting"],
    [47, "Male", "Collecting stamps"],
    [36, "Non-binary", "Playing board games"],
    [52, "Female", "Skiing"],
    [28, "Male", "Playing tennis"],
    [19, "Female", "Playing chess"],
    [44, "Male", "Playing soccer"],
    [31, "Female", "Baking"],
    [53, "Male", "Watching sports"],
    [18, "Non-binary", "Playing card games"],
    [38, "Female", "Cycling"],
    [45, "Male", "Swimming"],
    [24, "Female", "Surfing the internet"],
    [29, "Male", "Playing drums"],
    [56, "Female", "Watching TV"],
    [20, "Male", "Playing baseball"],
    [32, "Female", "Playing volleyball"],
    [47, "Male", "Watching movies"],
    [21, "Non-binary", "Singing"],
    [27, "Female", "Playing golf"],
    [54, "Male", "Cooking"],
    [16, "Female", "Taking photos"],
    [40, "Male", "Running"],
    [55, "Female", "Playing piano"],
    [22, "Male", "Playing basketball"],
    [30, "Female", "Camping"],
    [43, "Male", "Playing chess"],
    [23, "Non-binary", "Playing video games"],
    [35, "Female", "Swimming"],
    [51, "Male", "Building models"],
    [19, "Female", "Singing"],
    [33, "Male", "Surfing the internet"],
    [48, "Female", "Playing guitar"],
    [41, "Male", "Playing video games"],
    [34, "Female", "Hiking"],
    [46, "Male", "Watching TV"],
    [36, "Non-binary", "Cooking"],
    [53, "Female", "Playing tennis"],
    [28, "Male", "Playing soccer"],
    [17, "Female", "Paintball"],
    [39, "Male", "Going for walks"],
    [59, "Female", "Watching movies"],
    [21, "Male", "Playing video games"],
    [30, "Female", "Reading"],
    [44, "Male", "Playing piano"],
    [18, "Non-binary", "Listening to music"],
    [36, "Female", "Playing soccer"],
    [49, "Male", "Fishing"],
    [24, "Female", "Hiking"],
    [27, "Male", "Drawing"],
    [55, "Female", "Knitting"],
    [22, "Male", "Playing tennis"],
    [31, "Female", "Playing basketball"],
    [50, "Male", "Woodworking"],
    [19, "Non-binary", "Playing piano"],
    [43, "Female", "Sculpting"],
    [34, "Male", "Playing guitar"],
    [48, "Female", "Playing video games"],
    [39, "Male", "Fishing"],
    [33, "Female", "Watching sports"],
    [45, "Male", "Reading"],
    [21, "Non-binary", "Watching TV"],
    [29, "Female", "Taking photos"],
    [56, "Male", "Cooking"],
    [20, "Female", "Playing soccer"],
    [37, "Male", "Hiking"],
    [54, "Female", "Playing guitar"],
    [17, "Non-binary", "Playing video games"],
    [47, "Female", "Watching movies"]
]


users = pd.DataFrame(columns=cols, data=people)
users
# Out:
#     Age      Gender                Hobby
# 0    25        Male              Reading
# 1    31      Female               Hiking
# 2    50        Male            Gardening
# 3    18  Non-binary          Video games
# 4    42      Female                 Yoga
# ..  ...         ...                  ...
# 94   20      Female       Playing soccer
# 95   37        Male               Hiking
# 96   54      Female       Playing guitar
# 97   17  Non-binary  Playing video games
# 98   47      Female      Watching movies
#
# [99 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# Split the data into separate lists
ages = [person[0] for person in people]
hobbies = [person[2] for person in people]

# Create a scatter plot
plt.scatter(ages, hobbies)

# Set labels and title
plt.xlabel("Age")
plt.ylabel("Hobby")
plt.title("Ages and hobbies of 100 people")

# Display the plot
plt.show()

# %%
users.set_index('Age')
# Out:
#          Gender                Hobby
# Age
# 25         Male              Reading
# 31       Female               Hiking
# 50         Male            Gardening
# 18   Non-binary          Video games
# 42       Female                 Yoga
# ..          ...                  ...
# 20       Female       Playing soccer
# 37         Male               Hiking
# 54       Female       Playing guitar
# 17   Non-binary  Playing video games
# 47       Female      Watching movies
#
# [99 rows x 2 columns]

# %%
users.set_index('Age').sort_values(by='Age', ascending=True)
# Out:
#          Gender                Hobby
# Age
# 16       Female        Taking photos
# 16       Female      Watching movies
# 17   Non-binary   Listening to music
# 17   Non-binary  Playing video games
# 17       Female            Paintball
# ..          ...                  ...
# 55       Female              Singing
# 56         Male              Cooking
# 56       Female          Watching TV
# 59       Female      Watching movies
# 60       Female              Reading
#
# [99 rows x 2 columns]

# %%
users['Age'].plot()
# Out:
# <AxesSubplot: >

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame with some sample data
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
    'Age': [25, 30, 18, 42, 28],
    'Gender': ['Female', 'Male', 'Male', 'Male', 'Female'],
    'Hobby': ['Reading', 'Hiking', 'Video games', 'Gardening', 'Yoga']
}
df = pd.DataFrame(data)

# Create a bar chart of the ages in the DataFrame
df.plot(kind='bar', x='Name', y='Age')

# Set the axis labels and title
plt.xlabel('Name')
plt.ylabel('Age')
plt.title('Ages of People')

# Show the plot
plt.show()

# %%
users.reset_index(inplace=True)

# %%
users.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
users
# Out:
#     index  Age      Gender                Hobby
# 0       0   25        Male              Reading
# 1       1   31      Female               Hiking
# 2       2   50        Male            Gardening
# 3       3   18  Non-binary          Video games
# 4       4   42      Female                 Yoga
# ..    ...  ...         ...                  ...
# 94     94   20      Female       Playing soccer
# 95     95   37        Male               Hiking
# 96     96   54      Female       Playing guitar
# 97     97   17  Non-binary  Playing video games
# 98     98   47      Female      Watching movies
#
# [99 rows x 4 columns]

# %%
users['genders in binary'] = users['Gender'].apply(
    lambda x : 1 if x == 'Male' else (0 if x == 'Female' else None))

# %%
users
# Out:
#     index  Age      Gender                Hobby  genders in binary
# 0       0   25        Male              Reading                1.0
# 1       1   31      Female               Hiking                0.0
# 2       2   50        Male            Gardening                1.0
# 3       3   18  Non-binary          Video games                NaN
# 4       4   42      Female                 Yoga                0.0
# ..    ...  ...         ...                  ...                ...
# 94     94   20      Female       Playing soccer                0.0
# 95     95   37        Male               Hiking                1.0
# 96     96   54      Female       Playing guitar                0.0
# 97     97   17  Non-binary  Playing video games                NaN
# 98     98   47      Female      Watching movies                0.0
#
# [99 rows x 5 columns]

# %%
users.fillna("Not A Number")
# Out:
#     index  Age      Gender                Hobby genders in binary
# 0       0   25        Male              Reading               1.0
# 1       1   31      Female               Hiking               0.0
# 2       2   50        Male            Gardening               1.0
# 3       3   18  Non-binary          Video games      Not A Number
# 4       4   42      Female                 Yoga               0.0
# ..    ...  ...         ...                  ...               ...
# 94     94   20      Female       Playing soccer               0.0
# 95     95   37        Male               Hiking               1.0
# 96     96   54      Female       Playing guitar               0.0
# 97     97   17  Non-binary  Playing video games      Not A Number
# 98     98   47      Female      Watching movies               0.0
#
# [99 rows x 5 columns]

# %%
users
# Out:
#     index  Age      Gender                Hobby  genders in binary
# 0       0   25        Male              Reading                1.0
# 1       1   31      Female               Hiking                0.0
# 2       2   50        Male            Gardening                1.0
# 3       3   18  Non-binary          Video games                NaN
# 4       4   42      Female                 Yoga                0.0
# ..    ...  ...         ...                  ...                ...
# 94     94   20      Female       Playing soccer                0.0
# 95     95   37        Male               Hiking                1.0
# 96     96   54      Female       Playing guitar                0.0
# 97     97   17  Non-binary  Playing video games                NaN
# 98     98   47      Female      Watching movies                0.0
#
# [99 rows x 5 columns]

# %%
users['Gender'] == 'Male'
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4     False
#       ...
# 94    False
# 95     True
# 96    False
# 97    False
# 98    False
# Name: Gender, Length: 99, dtype: bool

# %%
users[users['Gender'] == 'Male']
# Out:
#     index  Age Gender                 Hobby  genders in binary
# 0       0   25   Male               Reading                1.0
# 2       2   50   Male             Gardening                1.0
# 5       5   28   Male        Playing guitar                1.0
# 7       7   36   Male               Cooking                1.0
# 9       9   24   Male               Running                1.0
# 11     11   45   Male               Fishing                1.0
# 14     14   48   Male               Golfing                1.0
# 16     16   27   Male    Playing basketball                1.0
# 18     18   39   Male           Woodworking                1.0
# 20     20   22   Male               Surfing                1.0
# 22     22   43   Male               Hunting                1.0
# 25     25   51   Male         Playing poker                1.0
# 27     27   26   Male   Playing video games                1.0
# 29     29   41   Male               Camping                1.0
# ...

# %%
users[users['Gender'].isna()]
# Out:
# Empty DataFrame
# Columns: [index, Age, Gender, Hobby, genders in binary]
# Index: []

# %%
users[users['Gender'].isin(['Male', 'Female'])]
# Out:
#     index  Age  Gender            Hobby  genders in binary
# 0       0   25    Male          Reading                1.0
# 1       1   31  Female           Hiking                0.0
# 2       2   50    Male        Gardening                1.0
# 4       4   42  Female             Yoga                0.0
# 5       5   28    Male   Playing guitar                1.0
# ..    ...  ...     ...              ...                ...
# 93     93   56    Male          Cooking                1.0
# 94     94   20  Female   Playing soccer                0.0
# 95     95   37    Male           Hiking                1.0
# 96     96   54  Female   Playing guitar                0.0
# 98     98   47  Female  Watching movies                0.0
#
# [87 rows x 5 columns]

# %%
users[~users['Gender'].isin(['Male', 'Female'])]
# Out:
#     index  Age      Gender                Hobby  genders in binary
# 3       3   18  Non-binary          Video games                NaN
# 12     12   20  Non-binary             Knitting                NaN
# 23     23   17  Non-binary   Listening to music                NaN
# 32     32   36  Non-binary  Playing board games                NaN
# 39     39   18  Non-binary   Playing card games                NaN
# 48     48   21  Non-binary              Singing                NaN
# 57     57   23  Non-binary  Playing video games                NaN
# 66     66   36  Non-binary              Cooking                NaN
# 75     75   18  Non-binary   Listening to music                NaN
# 84     84   19  Non-binary        Playing piano                NaN
# 91     91   21  Non-binary          Watching TV                NaN
# 97     97   17  Non-binary  Playing video games                NaN

# %%
users[~users['Gender'].isin(['Male', 'Female']) & (users['Age'] < 25)]
# Out:
#     index  Age      Gender                Hobby  genders in binary
# 3       3   18  Non-binary          Video games                NaN
# 12     12   20  Non-binary             Knitting                NaN
# 23     23   17  Non-binary   Listening to music                NaN
# 39     39   18  Non-binary   Playing card games                NaN
# 48     48   21  Non-binary              Singing                NaN
# 57     57   23  Non-binary  Playing video games                NaN
# 75     75   18  Non-binary   Listening to music                NaN
# 84     84   19  Non-binary        Playing piano                NaN
# 91     91   21  Non-binary          Watching TV                NaN
# 97     97   17  Non-binary  Playing video games                NaN

# %%
pd.read_csv('titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 pd.read_csv('titanic.csv')
#
# File ~/.conda/envs/jup/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.conda/envs/jup/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...
