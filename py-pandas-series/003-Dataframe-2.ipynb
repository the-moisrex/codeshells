# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#     seq firstname  lastname  age        street       city state    zip  \
# 0     1   Theresa     Welch   58  Nulmuh Place    Jovtore    TX   2916
# 1     2      Rose      Ball   61     Kono Park   Renzahep    TN  52100
# 2     3    Robert     Hines   50   Tuptu Manor   Kibcocac    DC  11864
# 3     4      Nora   Garrett   43    Ewmit Road    Ehluhec    MT  91108
# 4     5       Eva     Clark   42    Kapen Park    Genuwiv    UT  60085
# ..  ...       ...       ...  ...           ...        ...   ...    ...
# 95   96  Virginia     Tyler   39   Uteno Trail     Hiovzu    TN  43314
# 96   97    Sylvia    Haynes   32      Vuna Key   Kaoziupi    SC  38221
# 97   98     Daisy  Sandoval   47  Zuaba Square  Iwiecemaw    VA  74241
# 98   99   Kathryn   Higgins   39     Wije Pass    Lumijuz    AR  80293
# 99  100    Trevor    Larson   39  Zisiwe Point   Desihhij    IN   9116
#
#       dollar    pick        date
# 0   $7991.70   WHITE  03/21/1906
# 1   $2226.51   GREEN  12/07/2003
# ...

# %%
df['age'] > 50
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: age, Length: 100, dtype: bool

# %%
df[df['age'] > 50]
# Out:
#     seq  firstname   lastname  age           street       city state    zip  \
# 0     1    Theresa      Welch   58     Nulmuh Place    Jovtore    TX   2916
# 1     2       Rose       Ball   61        Kono Park   Renzahep    TN  52100
# 8     9      Peter     Valdez   54     Wani Heights    Jonemug    WI  41608
# 10   11        Eva      Marsh   58        Ruhca Key    Hoihabe    AL  61911
# 11   12    Cecelia     Morton   57        Jigu Lane  Jucboftis    CT  55081
# 22   23  Genevieve      Yates   52       Soah Ridge  Gabgipzem    CO   4908
# 24   25       Edna      Davis   57   Jetu Extension   Memsidcu    SD  87254
# 25   26     Evelyn     Adkins   53   Ludda Junction   Jocumlek    TN  96012
# 33   34      Lelia      Young   51      Elowu River  Nakulifud    ID  75987
# 34   35     Gordon    Burgess   51     Kigva Circle    Warkucu    KY  47996
# 35   36      Ollie       Bush   64      Bear Street    Neitema    OH   2556
# ...

# %%
df.reset_index(inplace=False)
# Out:
#     index  seq firstname  lastname  age        street       city state    zip  \
# 0       0    1   Theresa     Welch   58  Nulmuh Place    Jovtore    TX   2916
# 1       1    2      Rose      Ball   61     Kono Park   Renzahep    TN  52100
# 2       2    3    Robert     Hines   50   Tuptu Manor   Kibcocac    DC  11864
# 3       3    4      Nora   Garrett   43    Ewmit Road    Ehluhec    MT  91108
# 4       4    5       Eva     Clark   42    Kapen Park    Genuwiv    UT  60085
# ..    ...  ...       ...       ...  ...           ...        ...   ...    ...
# 95     95   96  Virginia     Tyler   39   Uteno Trail     Hiovzu    TN  43314
# 96     96   97    Sylvia    Haynes   32      Vuna Key   Kaoziupi    SC  38221
# 97     97   98     Daisy  Sandoval   47  Zuaba Square  Iwiecemaw    VA  74241
# 98     98   99   Kathryn   Higgins   39     Wije Pass    Lumijuz    AR  80293
# 99     99  100    Trevor    Larson   39  Zisiwe Point   Desihhij    IN   9116
#
#       dollar    pick        date
# ...

# %%
df.set_index('date', inplace=False)
# Out:
#             seq firstname  lastname  age        street       city state  \
# date
# 03/21/1906    1   Theresa     Welch   58  Nulmuh Place    Jovtore    TX
# 12/07/2003    2      Rose      Ball   61     Kono Park   Renzahep    TN
# 06/04/1930    3    Robert     Hines   50   Tuptu Manor   Kibcocac    DC
# 07/24/2054    4      Nora   Garrett   43    Ewmit Road    Ehluhec    MT
# 06/21/1957    5       Eva     Clark   42    Kapen Park    Genuwiv    UT
# ...         ...       ...       ...  ...           ...        ...   ...
# 04/29/1906   96  Virginia     Tyler   39   Uteno Trail     Hiovzu    TN
# 12/04/1958   97    Sylvia    Haynes   32      Vuna Key   Kaoziupi    SC
# 03/24/1987   98     Daisy  Sandoval   47  Zuaba Square  Iwiecemaw    VA
# 01/05/1924   99   Kathryn   Higgins   39     Wije Pass    Lumijuz    AR
# 05/26/1938  100    Trevor    Larson   39  Zisiwe Point   Desihhij    IN
#
#               zip    dollar    pick
# date
# 03/21/1906   2916  $7991.70   WHITE
# ...
