# %% [markdown]
# # py.nice-plot
#
#     Python Version:    Python 3.11.6
#     Conda Version:     conda 23.10.0
#     Conda Environment: jup
#     Conda Path:        $HOME/.conda/envs/jup

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ![image.png](attachment:88a09d9b-1256-45a2-bbb0-c25b080612a5.png)

# %% [markdown]
# ![image.png](attachment:815f87b3-9afa-4d90-b7f1-6725d57b3347.png)
