# %% [markdown]
# # Machine Learning -> Deep Learning -> 001
#
# ## 01 - A Summary of Deep Learning and Artificial Intelligence Landscape [Mph0cWZsoV4]
#
#     Python Version:    Python 3.10.9
#     Conda Version:     conda 23.1.0
#     Conda Environment: jup
#     Conda Path:        $HOME/.conda/envs/jup

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ![image.png](attachment:0988cf66-9aab-40c3-8b30-09c8a9b822d0.png)
