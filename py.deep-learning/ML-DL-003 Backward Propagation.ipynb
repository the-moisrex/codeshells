# %% [markdown]
# # ML > DL > 03 - Backward Propagation in Neural Networks explained
#
#     Python Version:    Python 3.10.9
#     Conda Version:     conda 23.1.0
#     Conda Environment: jup
#     Conda Path:        $HOME/.conda/envs/jup

# %% [markdown]
# # In training, at first:
#
# - Weight are initialized randomly
# - Biases are initialized with zero
#
# ![image.png](attachment:20ad1f43-c945-49ce-85b5-56fcfd562f73.png)

# %% [markdown]
# ## The Goal of Backpropogation:
#
# The goal is to see which parameters (weights, biases, and ...) are contributing to the ERROR.
#
#
# ![image.png](attachment:b6ae0581-d0a2-442a-a0ae-aea273857b37.png)
#
# ![image.png](attachment:fc44ac02-5d86-44f7-84e4-3c360c990a4b.png)
#
# ![image.png](attachment:b061e7f7-b901-4b7a-909e-5c22c9f0d2ee.png)

# %% [markdown]
# ## Back propogation:
#
# ![image.png](attachment:48299bc0-7351-4dff-8bc7-774ae36bbcd0.png)
