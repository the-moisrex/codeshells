# %% [markdown]
# # ML > DL > 002 > 02 - How Forward Propagation in Neural Networks works
#
#
#     Python Version:    Python 3.10.9
#     Conda Version:     conda 23.1.0
#     Conda Environment: jup
#     Conda Path:        $HOME/.conda/envs/jup

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ![image.png](attachment:6f45e6e8-7477-4a33-beab-b3717c6d4674.png)

# %% [markdown]
# ![image.png](attachment:baa1aa97-4157-41f4-8fa2-82e70dac413b.png)

# %% [markdown]
# ![image.png](attachment:fa0ab616-fb99-4ced-a428-91929037c79d.png)

# %% [markdown]
# b = Bias
#
# a = Activation Function

# %% [markdown]
# ![image.png](attachment:48329885-7f55-4a99-9eaf-1029d3265e63.png)

# %% [markdown]
# very layer has its own activation function
#
# ## Why we need activation function?
#
# - Because we need non-linearity: without activation function, everything is a linear function
# - Without a non-linear activation function, even the deepest network is as good as a single neuron
